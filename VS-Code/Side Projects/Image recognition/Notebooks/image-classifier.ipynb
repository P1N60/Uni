# %% [markdown]
# # Introduction

# %% [markdown]
# ## In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# ![image.png](attachment:978d2b09-eb28-4622-a998-0cb33881bf07.png)

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!

# %% [markdown]
# # Downloading requirements

# %%
#This helps widgets somehow
# %matplotlib inline

# %%
! pip install -Uq fastai fastbook duckduckgo_search ipywidgets

# %%
#hide
import fastbook
fastbook.setup_book()
from pathlib import Path

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # Preparing training- and validation set

# %% [markdown]
# ## Variable definitions

# %%
model_name = "Animal Classifier"
img_amount = 50 #images pr. category
img_quality = 224 #image quality in pixels

prefix = "Image of "
category_types = ['cat', 'dog', 'fish', 'mouse', 'hamster', 'racoon', 'fox', 'tiger']
suffix = ""

trainingFolder = Path.cwd().parent / 'Training data'
modelFolder = Path.cwd().parent.parent / 'Trained models'

# %% [markdown]
# ## Info for upcomming training

# %%
ttl_imgs = round(len(category_types)*img_amount)
epochs = round(ttl_imgs ** 0.225)
print(f'Toral images: {ttl_imgs}')
print(f'Expected epochs: {epochs}')
# Out:
# Toral images: 400
# Expected epochs: 4

# %% [markdown]
# ## Collecting images

# %%
from duckduckgo_search import DDGS
from fastcore.all import *
import shutil

print(trainingFolder)

# Clear the contents of the categories' directories if it already exists
if trainingFolder.exists():
    print(f"The '{trainingFolder}' dictionary already exists")
    shutil.rmtree(trainingFolder)
    print(f"Cleared the '{trainingFolder}' directory")

# Create the categories' directories and subdirectories, and download images
trainingFolder.mkdir(parents=True)
for o in category_types:
    dest = (trainingFolder/o)
    dest.mkdir(exist_ok=True)
    results = search_images_ddg(f"{prefix}{o}{suffix}", max_images=img_amount)
    download_images(dest, urls=results)
    print(f"Created new folder for: '{prefix}{o}{suffix}', and downloaded the images")

if trainingFolder.exists():
    print('All folders have been created successfully')
else:
    print(f"Something fucked up. The directory: '{trainingFolder}' does not exist")
# Out:
# /Users/victor/Documents/GitHub/VS-Code/Side Projects/Image recognition/Training data
# The '/Users/victor/Documents/GitHub/VS-Code/Side Projects/Image recognition/Training data' dictionary already exists
# Cleared the '/Users/victor/Documents/GitHub/VS-Code/Side Projects/Image recognition/Training data' directory
# Created new folder for: 'Image of cat', and downloaded the images
# Created new folder for: 'Image of dog', and downloaded the images
# Created new folder for: 'Image of fish', and downloaded the images
# Created new folder for: 'Image of mouse', and downloaded the images
# Created new folder for: 'Image of hamster', and downloaded the images
# Created new folder for: 'Image of racoon', and downloaded the images
# Created new folder for: 'Image of fox', and downloaded the images
# Created new folder for: 'Image of tiger', and downloaded the images
# All folders have been created successfully

# %% [markdown]
# ## Unlinking failed images

# %%
fns = get_image_files(trainingFolder)

failed = verify_images(fns)
print(f'Failed images: {len(failed)}')

failed.map(Path.unlink)
print('Unlinking complete')

print(f'Successful images: {len(fns)} ready for training')
# Out:
# Failed images: 12
# Unlinking complete
# Successful images: 366 ready for training

# %%
categories = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(size=img_quality, method='squish'))

# %%
dls = categories.dataloaders(trainingFolder)
dls.valid.show_batch(max_n=8, nrows=2, unique=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %% [markdown]
# ## Non-augmented or resized image example

# %%
dls = categories.dataloaders(trainingFolder)
dls.valid.show_batch(max_n=1, nrows=1, unique=True)

# %% [markdown]
# ## RandomResizedCrop examples

# %%
categories = categories.new(item_tfms=RandomResizedCrop(size=img_quality, min_scale=0.55))
dls = categories.dataloaders(trainingFolder)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## RandomResizedCrop & transform augmentation

# %%
categories = categories.new(item_tfms=Resize(size=img_quality), 
                batch_tfms=[Flip(), Rotate(max_deg=18), Zoom(min_zoom=1.0, max_zoom=1.20), 
                Brightness(max_lighting=0.3), Contrast(max_lighting=0.25)])
dls = categories.dataloaders(trainingFolder)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# # Training

# %%
print(f'Training for: {epochs} epochs')
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(epochs)
# Out:
# Training for: 4 epochs
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.598007</td>
#       <td>1.296815</td>
#       <td>0.400000</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.227239</td>
#       <td>0.628771</td>
#       <td>0.214286</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.910371</td>
#       <td>0.440808</td>
#       <td>0.142857</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.696545</td>
#       <td>0.410085</td>
#       <td>0.128571</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.550766</td>
#       <td>0.346127</td>
#       <td>0.142857</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Measureing where the model fails to interpret images correctly

# %% [markdown]
# ## Confusion matrix

# %%
interp = ClassificationInterpretation.from_learner(learn)

if len(category_types)<=50:
    interp.plot_confusion_matrix(normalize=True, norm_dec=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ## Classifications with the highest loss

# %%
interp.plot_top_losses(8, nrows=2, figsize=(17, 7))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ## Data-cleansing (optional)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('cat', 'dog', 'fish', 'fox', 'hamster', 'mouse', 'racoon', 'tiger'), value='c…

# %%
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,category in cleaner.change(): shutil.move(str(cleaner.fns[idx]), trainingFolder/category)

# %% [markdown]
# # Exporting our model

# %%
learn.export(modelFolder / f'{model_name}.pkl')
modelFolder.ls(file_exts=".pkl")
# Out:
# (#2) [Path('/Users/victor/Documents/GitHub/VS-Code/Side Projects/Trained models/Animal Classifier.pkl'),Path('/Users/victor/Documents/GitHub/VS-Code/Side Projects/Trained models/league_champion_classifier.pkl')]

# %% [markdown]
# # Testing our model with widgets

# %%
learn_inf = load_learner(modelFolder / f'{model_name}.pkl')
learn_inf

# %%
#hide_output
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(448,448))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred} | Probability: {probs[pred_idx]:.02f}'

btn_run.on_click(on_click_classify)

VBox([btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(FileUpload(value={}, description='Upload'), Button(description='Classify', style=ButtonStyle())…
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
