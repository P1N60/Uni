# %%
def fileReader(path):
    with open(path, 'r') as file:
        lines = file.readlines()
    return [line.strip() for line in lines]

# %%
data = fileReader('el-prices.csv')
print(data)
data = data[1:(len(data))]
print(data)
# Out:
# ['Start,Elpris,"Transport og afgifter",Total', '"13.12.2024 - 23:00","1,24","1,47","2,71"', '"13.12.2024 - 22:00","1,42","1,47","2,89"', '"13.12.2024 - 21:00","1,52","1,47","2,99"', '"13.12.2024 - 20:00","1,79","2,21","4,00"', '"13.12.2024 - 19:00","2,26","2,21","4,47"', '"13.12.2024 - 18:00","2,58","2,21","4,79"', '"13.12.2024 - 17:00","2,81","2,21","5,02"', '"13.12.2024 - 16:00","2,49","1,47","3,96"', '"13.12.2024 - 15:00","2,22","1,47","3,69"', '"13.12.2024 - 14:00","1,88","1,47","3,35"', '"13.12.2024 - 13:00","1,70","1,47","3,17"', '"13.12.2024 - 12:00","1,71","1,47","3,18"', '"13.12.2024 - 11:00","1,78","1,47","3,25"', '"13.12.2024 - 10:00","2,10","1,47","3,57"', '"13.12.2024 - 09:00","2,45","1,47","3,92"', '"13.12.2024 - 08:00","2,52","1,47","3,99"', '"13.12.2024 - 07:00","1,91","1,47","3,38"', '"13.12.2024 - 06:00","1,62","1,47","3,09"', '"13.12.2024 - 05:00","1,33","1,23","2,56"', '"13.12.2024 - 04:00","1,24","1,23","2,47"', '"13.12.2024 - 03:00","1,23","1,23","2,46"', '"13.1
# ...

# %%
def dataStore(row):
    return data[row]

# %%
dataStore(0)
# Out:
# '"13.12.2024 - 23:00","1,24","1,47","2,71"'

# %%
# Convert to tuples
def listToTuple(list):
    i = 0
    x = []
    while i < len(list)-3:
        tuple = (list[0+i])
        i += 1
        x.append(tuple)
    return x
data = listToTuple(data)
print(data)
# Out:
# [('"13.12.2024 - 23:00","1,24","1,47","2,71"', '"13.12.2024 - 22:00","1,42","1,47","2,89"', '"13.12.2024 - 21:00","1,52","1,47","2,99"', '"13.12.2024 - 20:00","1,79","2,21","4,00"'), ('"13.12.2024 - 22:00","1,42","1,47","2,89"', '"13.12.2024 - 21:00","1,52","1,47","2,99"', '"13.12.2024 - 20:00","1,79","2,21","4,00"', '"13.12.2024 - 19:00","2,26","2,21","4,47"'), ('"13.12.2024 - 21:00","1,52","1,47","2,99"', '"13.12.2024 - 20:00","1,79","2,21","4,00"', '"13.12.2024 - 19:00","2,26","2,21","4,47"', '"13.12.2024 - 18:00","2,58","2,21","4,79"'), ('"13.12.2024 - 20:00","1,79","2,21","4,00"', '"13.12.2024 - 19:00","2,26","2,21","4,47"', '"13.12.2024 - 18:00","2,58","2,21","4,79"', '"13.12.2024 - 17:00","2,81","2,21","5,02"'), ('"13.12.2024 - 19:00","2,26","2,21","4,47"', '"13.12.2024 - 18:00","2,58","2,21","4,79"', '"13.12.2024 - 17:00","2,81","2,21","5,02"', '"13.12.2024 - 16:00","2,49","1,47","3,96"'), ('"13.12.2024 - 18:00","2,58","2,21","4,79"', '"13.12.2024 - 17:00","2,81","2,21","5,02
# ...
